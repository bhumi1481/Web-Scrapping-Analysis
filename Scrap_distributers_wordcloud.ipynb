# %%
from bs4 import BeautifulSoup

with open("https://news.google.com/?hl=en-IN&gl=IN&ceid=IN:en") as fp:
    soup = BeautifulSoup(fp)

soup = BeautifulSoup("<html>data</html>")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-8b9f8f82abb3> in <module>
#       1 from bs4 import BeautifulSoup
#       2
# ----> 3 with open("https://news.google.com/?hl=en-IN&gl=IN&ceid=IN:en") as fp:
#       4     soup = BeautifulSoup(fp)
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'https://news.google.com/?hl=en-IN&gl=IN&ceid=IN:en'

# %%
import requests
import bs4
res=requests.get('https://news.google.com/?hl=en-IN&gl=IN&ceid=IN:en')
type(res)
# Out:
# requests.models.Response

# %%
res.text
# Out:
# '<!doctype html><html lang="en" dir="ltr"><head><base href="https://news.google.com/"><meta name="referrer" content="origin"><link rel="canonical" href="https://news.google.com/"><meta name="viewport" content="width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no,minimal-ui"><meta name="apple-itunes-app" content="app-id=459182288"><link rel="shortcut icon" href="https://lh3.googleusercontent.com/-Ywb4dKmVqHQJnSvbou08pw78G-XvfVk4xp-6zrBgHE8aTCfugOeLqXJPhDOic6JeKL0LHYbUw=w16" sizes="16x16"><link rel="shortcut icon" href="https://lh3.googleusercontent.com/-Ywb4dKmVqHQJnSvbou08pw78G-XvfVk4xp-6zrBgHE8aTCfugOeLqXJPhDOic6JeKL0LHYbUw=w24" sizes="24x24"><link rel="shortcut icon" href="https://lh3.googleusercontent.com/-Ywb4dKmVqHQJnSvbou08pw78G-XvfVk4xp-6zrBgHE8aTCfugOeLqXJPhDOic6JeKL0LHYbUw=w32" sizes="32x32"><link rel="shortcut icon" href="https://lh3.googleusercontent.com/-Ywb4dKmVqHQJnSvbou08pw78G-XvfVk4xp-6zrBgHE8aTCfugOeLqXJPhDOic6JeKL0LHYbUw=w48" sizes="48
# ...

# %%
soup=bs4.BeautifulSoup(res.text,'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
hi=soup.select('title')

# %%
hi
# Out:
# [<title>Google News</title>]

# %%
hi[0].getText()
# Out:
# 'Google News'

# %%
import requests
import bs4


res=requests.get('https://www.ndtv.com/food/want-to-stick-to-a-healthy-diet-have-your-high-calorie-desserts-first-say-scientists-1990507')
res1=requests.get('https://www.news18.com/news/lifestyle/heres-what-you-need-to-know-about-a-nagging-backache-2030039.html')

soup=bs4.BeautifulSoup(res.text,'lxml')
soup1=bs4.BeautifulSoup(res1.text,'lxml')

s1=[]
s=[]
for i in soup.select('p'):

    s.append(i.text)
for i in soup1.select('#article_body'):

    s1.append(i.text)

s.append(s1)
print(s)

import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS


def random_color_func(word=None, font_size=None, position=None, orientation=None, font_path=None, random_state=None):
    h = int(360.0 * 45.0 / 255.0)
    s = int(100.0 * 255.0 / 255.0)
    l = int(100.0 * float(random_state.randint(60, 120)) / 255.0)

    return "hsl({}, {}%, {}%)".format(h, s, l)

file_content=s[7]

wordcloud = WordCloud(
                            stopwords = STOPWORDS,
                            background_color = 'white',
                            width = 1200,
                            height = 1000,
                            color_func = random_color_func
                            ).generate(file_content)

plt.imshow(wordcloud)
plt.axis('off')
plt.show()
# Out:
# ['Sections', 'It has been emphasised often enough, that switching to a healthy diet would require you to quit all things sugary and greasy for good. But if the feat is too challenging for you, you may make some changes in the sequence in which you have your food. If the findings of a latest study are to be believed, consuming a high-calorie dessert at the beginning of your meal can actually make you opt for a healthier course.', 'The findings said that if you choose the dessert first, you may maximise your chances of sticking to a healthier diet plan. For the study, the researchers placed either a healthy or less healthy dessert (fresh fruit vs. lemon cheesecake) at the beginning or end of a university cafeteria line.', 'The researchers said that if the diners picked the cheesecake first, they often chose lower-calorie main or side dishes later. This way they consumed fewer calories than diners who opted for the fresh fruit first.', 'We believe diners who chose the indulgent dessert 
# ...

# %%
#for link in soup.find_all(href = True):
  #  if link['href'] != "#" :
   #     print("\n",link["href"]) 
# importing all necessery modules

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS


def random_color_func(word=None, font_size=None, position=None, orientation=None, font_path=None, random_state=None):
    h = int(360.0 * 45.0 / 255.0)
    s = int(100.0 * 255.0 / 255.0)
    l = int(100.0 * float(random_state.randint(60, 120)) / 255.0)

    return "hsl({}, {}%, {}%)".format(h, s, l)

file_content=s[0]

wordcloud = WordCloud(
                            stopwords = STOPWORDS,
                            background_color = 'white',
                            width = 1200,
                            height = 1000,
                            color_func = random_color_func
                            ).generate(file_content)

plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
import sys
print(sys.executable)
# Out:
# /usr/bin/python3

# %%
import bs4 as bs
import urllib.request

sauce=urllib.request.urlopen('https://www.ndtv.com/india-news/triple-talaq-bill-taken-up-by-lok-sabha-after-tweaks-10-points-1968807').read()
soup=bs.BeautifulSoup(sauce,'lxml')
#print(soup.finad_all('p'))


for para in soup.find_all('p'):
    print(para.text)
# Out:
# Sections
# "Triple talaq" in Lok Sabha: Members of the Lok Sabha are debating the "triple talaq" bill
# ................................ Advertisement ................................
# ................................ Advertisement ................................
# ................................ Advertisement ................................

# %%
import requests
import bs4
res=requests.get('https://www.moneycontrol.com/news/business/economy/comment-who-is-right-rbi-or-its-panel-of-professional-forecasters-3501311.html')
type(res)
soup=bs4.BeautifulSoup(res.text,'lxml')
type(soup)
s=[]
for i in soup.select('.arti-flow'):
    s.append(i.text)
re=soup.select('.arti-flow')

print(s)
for i in soup.select('.arti-flow'):

    print(i.text)
# Out:
# ['\nThe reason for the Reserve Bank of India’s (RBI) 25 basis point rate cut was its assessment that inflation will remain very tame. The monetary policy statement says consumer price inflation will be 2.8 percent during January-March; 3.2 to 3.4 percent for April-September; and 3.9 percent during October-December. Since the RBI’s inflation target is 4 percent per annum, there’s ample reason for the central bank to cut rates.But will inflation really be that low? The RBI conducts a survey of professional forecasters once every two months. The latest survey, the results of which were announced together with the monetary policy on February 7, doesn’t agree with RBI’s forecasts.The RBI’s monetary policy statement says, “The short-term outlook for food inflation appears particularly benign, despite adverse base effects.” In sharp contrast, the survey of professional forecasters says, “Consumer price inflation is expected to increase in Q4 FY19, firm up further and remain above 4 percent 
# ...

# %%
import requests
import bs4
res=requests.get('https://news.google.com/?hl=en-IN&gl=IN&ceid=IN:en')
type(res)
soup=bs4.BeautifulSoup(res.text,'lxml')
type(soup)
s=[]
for i in soup.select('.KbnJ8'):
    s.append(i.text)
#    print(i.text)
re=soup.select('.KbnJ8')

print(s)
# Out:
# ['News18', 'Times of India', 'Scroll.in', 'The Quint', 'The Quint', 'Times of India', 'The Hindu', 'NDTV News', 'Times of India', 'News18', 'Moneycontrol.com', 'NDTV News', 'News18', 'The News Minute', 'News18', 'NDTV News', 'News18', 'The Indian Express', 'NDTV News', 'Hindustan Times', 'NDTV News', 'Economic Times', 'The Indian Express', 'NDTV', 'The News Minute', 'Times Now', 'NDTV News', 'Times of India', 'Times Now', 'NDTV News', 'NDTV News', 'Hindustan Times', 'News18', 'Moneycontrol.com', 'Hindustan Times', 'Hindustan Times', 'NDTV News', 'Hindustan Times', 'Firstpost', 'NDTV News', 'Times of India', 'News18', 'NDTV News', 'The Hindu', 'Times Now', 'Times of India', 'The Guardian', 'The Independent', 'Economic Times', 'NDTV News', 'Livemint', 'Times of India', 'Business Today', 'Moneycontrol.com', 'Economic Times', 'Economic Times', 'Hindustan Times', 'Livemint', 'Moneycontrol.com', 'Economic Times', 'Indiainfoline', 'Moneycontrol.com', 'Economic Times', 'The Indian Express', 
# ...

# %%
import numpy as np
a = np.asarray( s )
#print("Original array:")
#print(len(a))
unique_elements, counts_elements = np.unique(a, return_counts=True)
#print("Frequency of unique values of the said array:")
#print("Total uniques:",len(unique_elements))
#print(np.asarray((unique_elements)))
import matplotlib.pyplot as plt
new=[]
for i in a:
    new.append(i.replace(" ",""))
unique_string=(" ").join(new)
wordcloud = WordCloud(width = 1000, height = 500).generate(unique_string)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.savefig("your_file_name"+".png", bbox_inches='tight')
plt.show()
plt.close()

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS


def random_color_func(word=None, font_size=None, position=None, orientation=None, font_path=None, random_state=None):
    h = int(360.0 * 45.0 / 255.0)
    s = int(100.0 * 255.0 / 255.0)
    l = int(100.0 * float(random_state.randint(60, 120)) / 255.0)

    return "hsl({}, {}%, {}%)".format(h, s, l)

file_content=unique_elements

wordcloud = WordCloud(
                            stopwords = STOPWORDS,
                            background_color = 'white',
                            width = 1200,
                            height = 1000,
                            color_func = random_color_func
                            ).generate(file_content)

plt.imshow(wordcloud)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-a73c8e350e13> in <module>
#      18                             height = 1000,
#      19                             color_func = random_color_func
# ---> 20                             ).generate(file_content)
#      21
#      22 plt.imshow(wordcloud)
#
# /usr/local/lib/python3.6/dist-packages/wordcloud/wordcloud.py in generate(self, text)
#     603         self
#     604         """
# --> 605         return self.generate_from_text(text)
#     606
#     607     def _check_generated(self):
#
# /usr/local/lib/python3.6/dist-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     584         self
#     585         """
# --> 586         words = self.process_text(text)
#     587         self.generate_from_frequencies(words)
#     588         return self
#
# ...
